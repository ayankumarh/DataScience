# %% [markdown]
# <a href="https://colab.research.google.com/github/ayankumarh/DataScience/blob/master/Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models, preprocessing
import tensorflow_datasets as tfds

max_len = 200
n_words = 10000
dim_embedding = 256
EPOCHS = 20
BATCH_SIZE = 500

def load_data():
  # Load data.
  (X_train, y_train), (X_test, y_test) = datasets.imdb.load_data(num_words=n_words)
  # Pad sequences with max_len.
  X_train = preprocessing.sequence.pad_sequences(X_train, maxlen=max_len)
  X_test = preprocessing.sequence.pad_sequences(X_test, maxlen=max_len)
  return (X_train, y_train), (X_test, y_test)

def build_model():
  model = models.Sequential()
  # Input:- eEmbedding Layer.
  # The model will take as input an integer matrix of size (batch,
  # input_length).
  # The model will output dimension (input_length, dim_embedding).
  # The largest integer in the input should be no larger than n_words (vocabulary size).
  model.add(layers.Embedding(n_words, dim_embedding, input_length=max_len))
  model.add(layers.Dropout(0.3))

  # Takes the maximum value of either feature vector from each of the
  # n_words features.
  model.add(layers.GlobalMaxPooling1D())
  model.add(layers.Dense(128, activation='relu'))
  model.add(layers.Dropout(0.5))
  model.add(layers.Dense(1, activation='sigmoid'))

  return model

(X_train, y_train), (X_test, y_test) = load_data()
model = build_model()
model.summary()

model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

score = model.fit(X_train, y_train,
                  epochs = EPOCHS,
                  batch_size = BATCH_SIZE,
                  validation_data = (X_test, y_test)
                  )

score = model.evaluate(X_test, y_test, batch_size=BATCH_SIZE)
print("\n Test score:", score[0])
print('Test accuracy:', score[1])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17465344/17464789 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 200, 256)          2560000
# _________________________________________________________________
# dropout (Dropout)            (None, 200, 256)          0
# _________________________________________________________________
# global_max_pooling1d (Global (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 2,593,025
# Trainable params: 2,593,025
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 50/50 [==============================] - 20s 397ms/step - loss: 0.6712 - accuracy: 0.6226 - val_loss: 0.6300 - val_accuracy: 0.8387
# Epoch 2/20
# 50/50 [==============================] - 20s 391ms/step - loss: 0.4659 - accuracy: 0.8406 - val_loss: 0.3695 - val_accuracy: 0.8586
# Epoch 3/20
# 50/50 [==============================] - 20s 395ms/step - loss: 0.2829 - accuracy: 0.8856 - val_loss: 0.3105 - val_accuracy: 0.8698
# Epoch 4/20
# 50/50 [==============================] - 20s 397ms/step - loss: 0.2180 - accuracy: 0.9142 - val_loss: 0.2933 - val_accuracy: 0.8749
# Epoch 5/20
# 50/50 [==============================] - 20s 398ms/step - loss: 0.1743 - accuracy: 0.9366 - val_loss: 0.2895 - val_accuracy: 0.8772
# Epoch 6/20
# 50/50 [==============================] - 20s 399ms/step - loss: 0.1360 - accuracy: 0.9530 - val_loss: 0.2939 - val_accuracy: 0.8733
# Epoch 7/20
# 50/50 [==============================] - 20s 398ms/step - loss: 0.1031 - accuracy: 0.9679 - val_loss: 0.3047 - val_accuracy: 0.8671
# Epoch 8/20
# 50/50 [==============================] - 20s 396ms/step - loss: 0.0787 - accuracy: 0.9780 - val_loss: 0.3265 - val_accuracy: 0.8612
# Epoch 9/20
# 50/50 [==============================] - 20s 396ms/step - loss: 0.0593 - accuracy: 0.9840 - val_loss: 0.3328 - val_accuracy: 0.8627
# Epoch 10/20
# 50/50 [==============================] - 20s 392ms/step - loss: 0.0436 - accuracy: 0.9895 - val_loss: 0.3509 - val_accuracy: 0.8596
# Epoch 11/20
# 50/50 [==============================] - 20s 393ms/step - loss: 0.0340 - accuracy: 0.9928 - val_loss: 0.3690 - val_accuracy: 0.8573
# Epoch 12/20
# 50/50 [==============================] - 20s 397ms/step - loss: 0.0261 - accuracy: 0.9949 - val_loss: 0.3877 - val_accuracy: 0.8553
# Epoch 13/20
# 50/50 [==============================] - 20s 394ms/step - loss: 0.0202 - accuracy: 0.9967 - val_loss: 0.3971 - val_accuracy: 0.8562
# Epoch 14/20
# 50/50 [==============================] - 20s 397ms/step - loss: 0.0163 - accuracy: 0.9970 - val_loss: 0.4161 - val_accuracy: 0.8543
# Epoch 15/20
# 50/50 [==============================] - 20s 399ms/step - loss: 0.0135 - accuracy: 0.9977 - val_loss: 0.4319 - val_accuracy: 0.8529
# Epoch 16/20
# 50/50 [==============================] - 20s 397ms/step - loss: 0.0116 - accuracy: 0.9979 - val_loss: 0.4449 - val_accuracy: 0.8520
# Epoch 17/20
# 50/50 [==============================] - 20s 397ms/step - loss: 0.0093 - accuracy: 0.9986 - val_loss: 0.4572 - val_accuracy: 0.8505
# Epoch 18/20
# 50/50 [==============================] - 20s 403ms/step - loss: 0.0081 - accuracy: 0.9988 - val_loss: 0.4697 - val_accuracy: 0.8496
# Epoch 19/20
# 50/50 [==============================] - 20s 401ms/step - loss: 0.0065 - accuracy: 0.9991 - val_loss: 0.4837 - val_accuracy: 0.8506
# Epoch 20/20
# 50/50 [==============================] - 20s 406ms/step - loss: 0.0060 - accuracy: 0.9992 - val_loss: 0.4974 - val_accuracy: 0.8491
# 50/50 [==============================] - 2s 32ms/step - loss: 0.4974 - accuracy: 0.8491
#
#  Test score: 0.4973885416984558
# Test accuracy: 0.8490800261497498
